# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.3 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.3 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 1.8/8.3 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.3 MB 1.7 MB/s eta 0:00:04
# ...

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# plt.style.use("ggplot")

# %% [markdown]
# # Carga del Dataset

# %%
file_path= "dataset/sorted_labeled_dataset_Gowalla_Dallas_Austin_with_local_time.csv"
df=pd.read_csv(file_path)
df.head()
# Out:
#    user_id  POI_id  POI_catid       POI_catname   latitude  longitude  \
# 0        1    8957        150          Fountain  32.942222 -97.131213
# 1        1    8956        125         City Hall  32.942655 -97.131200
# 2        1    9208        363          Chipotle  32.938825 -97.104131
# 3        1    9066        121  Corporate Office  32.794418 -96.800001
# 4        1  883057        433         Starbucks  32.942688 -97.130645
#
#    timezone_offset                   utc_time                 local_time
# 0             -360  2009-02-17 19:29:05+00:00  2009-02-17 13:29:05+00:00
# 1             -360  2009-02-17 19:30:20+00:00  2009-02-17 13:30:20+00:00
# 2             -360  2009-02-18 18:51:40+00:00  2009-02-18 12:51:40+00:00
# 3             -360  2009-02-19 23:02:50+00:00  2009-02-19 17:02:50+00:00
# 4             -360  2009-02-20 16:21:54+00:00  2009-02-20 10:21:54+00:00

# %%
print("Shape" , df.shape) #For rows and columns
# Out:
# Shape (684326, 9)

# %%
df.columns #All the names of the columns in the dataset.
# Out:
# Index(['user_id', 'POI_id', 'POI_catid', 'POI_catname', 'latitude',
#        'longitude', 'timezone_offset', 'utc_time', 'local_time'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684326 entries, 0 to 684325
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          684326 non-null  int64
#  1   POI_id           684326 non-null  int64
#  2   POI_catid        684326 non-null  int64
#  3   POI_catname      684326 non-null  object
#  4   latitude         684326 non-null  float64
#  5   longitude        684326 non-null  float64
#  6   timezone_offset  684326 non-null  int64
#  7   utc_time         684326 non-null  object
#  8   local_time       684326 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 47.0+ MB

# %% [markdown]
# # Exploración del dataset

# %% [markdown]
# #### Valores nulos

# %%
df.isnull()
# Out:
#         user_id  POI_id  POI_catid  POI_catname  latitude  longitude  \
# 0         False   False      False        False     False      False
# 1         False   False      False        False     False      False
# 2         False   False      False        False     False      False
# 3         False   False      False        False     False      False
# 4         False   False      False        False     False      False
# ...         ...     ...        ...          ...       ...        ...
# 684321    False   False      False        False     False      False
# 684322    False   False      False        False     False      False
# 684323    False   False      False        False     False      False
# 684324    False   False      False        False     False      False
# 684325    False   False      False        False     False      False
#
#         timezone_offset  utc_time  local_time
# 0                 False     False       False
# ...

# %%
df.isnull().sum()
# Out:
# user_id            0
# POI_id             0
# POI_catid          0
# POI_catname        0
# latitude           0
# longitude          0
# timezone_offset    0
# utc_time           0
# local_time         0
# dtype: int64

# %% [markdown]
# #### Valores duplicados

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 684321    False
# 684322    False
# 684323    False
# 684324    False
# 684325    False
# Length: 684326, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(919)

# %%
df.describe()
# Out:
#             user_id        POI_id      POI_catid       latitude  \
# count  6.843260e+05  6.843260e+05  684326.000000  684326.000000
# mean   1.969189e+05  7.967142e+05     153.325263      31.969944
# std    4.532381e+05  1.561537e+06     165.368521       1.233477
# min    1.000000e+00  8.932000e+03       1.000000      29.895557
# 25%    5.153000e+03  2.892200e+04      45.000000      30.291099
# 50%    5.008200e+04  2.071110e+05     114.000000      32.783582
# 75%    1.919120e+05  7.798700e+05     186.000000      32.909829
# max    2.644223e+06  7.712011e+06     933.000000      33.254791
#
#            longitude  timezone_offset
# count  684326.000000         684326.0
# mean      -97.227425           -360.0
# std         0.424984              0.0
# min       -98.140385           -360.0
# 25%       -97.739024           -360.0
# 50%       -97.130605           -360.0
# 75%       -96.807522           -360.0
# max       -96.298416           -360.0

# %% [markdown]
# #### Valores unicos

# %%
df['user_id'].nunique()
# Out:
# 2954

# %%
df['POI_id'].nunique()
# Out:
# 56890

# %%
df['POI_catid'].nunique()
# Out:
# 399

# %%
df['latitude'].nunique()
# Out:
# 56525

# %%
df['longitude'].nunique()
# Out:
# 56218

# %%
df['utc_time'].head() , df['local_time'].head()
# Out:
# (0    2009-02-17 19:29:05+00:00
#  1    2009-02-17 19:30:20+00:00
#  2    2009-02-18 18:51:40+00:00
#  3    2009-02-19 23:02:50+00:00
#  4    2009-02-20 16:21:54+00:00
#  Name: utc_time, dtype: object,
#  0    2009-02-17 13:29:05+00:00
#  1    2009-02-17 13:30:20+00:00
#  2    2009-02-18 12:51:40+00:00
#  3    2009-02-19 17:02:50+00:00
#  4    2009-02-20 10:21:54+00:00
#  Name: local_time, dtype: object)
